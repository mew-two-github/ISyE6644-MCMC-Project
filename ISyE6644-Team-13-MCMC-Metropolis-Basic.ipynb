# %%
import numpy as np
import pandas as pd
import random as rand
import matplotlib.pyplot as plt

# %%
rand.seed(36)

# %% [markdown]
# 100 Samples

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [i for i in theta]

n_steps = 100
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 1,000 Samples

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [i for i in theta]

n_steps = 1000
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
#stats_count
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 10,000 Samples

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [i for i in theta]

n_steps = 10000
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 100,000 Samples

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [i for i in theta]

n_steps = 100000
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 100 Trials for unknown Distribution

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [(i**2)*np.exp(-0.5*i) for i in theta]

n_steps = 100
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 100,000 Trials for unknown Distribution

# %%
n_states = 10
theta = [i for i in range(1,n_states+1)]
pi_theta = [(i**2)*np.exp(-0.5*i) for i in theta]

n_steps = 100000
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 100 Trials for unknown distribution 2

# %%
n_states = 20
theta = [i for i in range(1,n_states+1)]
pi_theta = [((i*2*i*3*i)*(np.exp(-1*i/3))) for i in theta]

n_steps = 100
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/(pi_theta[current-1]))
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
#plt.plot(theta, overal_dist, color='r')
plt.show()

# %% [markdown]
# 100,000 Trials for unknown distribution 2

# %%
n_states = 20
theta = [i for i in range(1,n_states+1)]
pi_theta = [((i*2*i*3*i)*(np.exp(-i/3))) for i in theta]

n_steps = 100000
theta_sim = pd.Series() # initialize
theta_sim[1] = 3 # initialize starting point

for i in range(2,n_steps+1):
    current = theta_sim[i - 1]
    proposed = rand.choices([current+1, current-1], [1, 1])[0]
    if not proposed in theta:
        theta_sim[i] = current
        continue
    a = min(1, pi_theta[proposed-1]/pi_theta[current-1])
    theta_sim[i] = rand.choices([proposed, current], [a, 1-a])[0]

states, counts = np.unique(theta_sim, return_counts=True)
stats_count = { k:v/n_steps for (k,v) in zip(states, counts) }
overal_dist = [i/sum(pi_theta) for i in pi_theta]

# %%
plt.bar(stats_count.keys(), stats_count.values())
plt.plot(theta, overal_dist, color='r')
plt.show()
